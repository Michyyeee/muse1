# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-91874b305a32> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     247       wrote_to_fifo = True
#     248     elif case == 5:
# --> 249       raise ValueError('mount failed: invalid oauth code')
#     250   if not wrote_to_fifo:
#     251     with open(fifo, 'w') as fifo_file:
#
# ValueError: mount failed: invalid oauth code

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !pip install -q keras

# %%
# !python3 "/content/drive/My Drive/app/mnist_cnn.py"
# Out:
# 2020-09-08 12:37:32.194497: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# 2020-09-08 12:37:34.135735: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-08 12:37:34.181444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:34.182008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-09-08 12:37:34.182048: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-08 12:37:34.430822: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-09-08 12:37:34.559610: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-09-08 12:37:34.583552: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-09-08 12:37:34.843857: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-09-08 12:37:34.864842: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-09-08 12:37:35.375319: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-09-08 12:37:35.375606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:35.376299: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:35.376818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-09-08 12:37:35.393595: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-09-08 12:37:35.393959: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x161cbc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-08 12:37:35.393992: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-08 12:37:35.541847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:35.542655: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x161ca00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-09-08 12:37:35.542685: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-09-08 12:37:35.543911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:35.544452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-09-08 12:37:35.544497: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-08 12:37:35.544535: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-09-08 12:37:35.544564: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-09-08 12:37:35.544583: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-09-08 12:37:35.544601: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-09-08 12:37:35.544618: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-09-08 12:37:35.544637: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-09-08 12:37:35.544709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:35.545306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:35.545988: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-09-08 12:37:35.551066: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-08 12:37:39.568914: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-08 12:37:39.568981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-09-08 12:37:39.568997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-09-08 12:37:39.574322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:39.574948: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-08 12:37:39.575483: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-09-08 12:37:39.575539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14968 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Epoch 1/12
# 2020-09-08 12:37:40.385284: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-09-08 12:37:41.829980: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 469/469 [==============================] - 3s 6ms/step - loss: 2.2767 - accuracy: 0.1488 - val_loss: 2.2249 - val_accuracy: 0.3388
# Epoch 2/12
# 469/469 [==============================] - 3s 5ms/step - loss: 2.1981 - accuracy: 0.2635 - val_loss: 2.1278 - val_accuracy: 0.5423
# Epoch 3/12
# 469/469 [==============================] - 3s 5ms/step - loss: 2.0961 - accuracy: 0.3827 - val_loss: 1.9987 - val_accuracy: 0.6414
# Epoch 4/12
# 469/469 [==============================] - 3s 5ms/step - loss: 1.9628 - accuracy: 0.4775 - val_loss: 1.8287 - val_accuracy: 0.7024
# Epoch 5/12
# 469/469 [==============================] - 3s 5ms/step - loss: 1.7950 - accuracy: 0.5470 - val_loss: 1.6217 - val_accuracy: 0.7376
# Epoch 6/12
# 469/469 [==============================] - 3s 5ms/step - loss: 1.6128 - accuracy: 0.5931 - val_loss: 1.4029 - val_accuracy: 0.7637
# Epoch 7/12
# 469/469 [==============================] - 3s 5ms/step - loss: 1.4302 - accuracy: 0.6251 - val_loss: 1.2009 - val_accuracy: 0.7878
# Epoch 8/12
# 469/469 [==============================] - 3s 5ms/step - loss: 1.2777 - accuracy: 0.6538 - val_loss: 1.0333 - val_accuracy: 0.8064
# Epoch 9/12
# 469/469 [==============================] - 3s 5ms/step - loss: 1.1538 - accuracy: 0.6762 - val_loss: 0.9027 - val_accuracy: 0.8187
# Epoch 10/12
# 469/469 [==============================] - 3s 5ms/step - loss: 1.0536 - accuracy: 0.6967 - val_loss: 0.8028 - val_accuracy: 0.8287
# Epoch 11/12
# 469/469 [==============================] - 3s 5ms/step - loss: 0.9805 - accuracy: 0.7098 - val_loss: 0.7278 - val_accuracy: 0.8389
# Epoch 12/12
# 469/469 [==============================] - 3s 5ms/step - loss: 0.9159 - accuracy: 0.7281 - val_loss: 0.6688 - val_accuracy: 0.8466
# Test loss: 0.6688295602798462
# Test accuracy: 0.8465999960899353

# %%
# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -P "/content/drive/My Drive/app"
# Out:
# --2020-09-08 12:39:12--  https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170 (1.1K) [text/plain]
# Saving to: ‘/content/drive/My Drive/app/Titanic.csv’
#
# Titanic.csv         100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2020-09-08 12:39:12 (46.5 MB/s) - ‘/content/drive/My Drive/app/Titanic.csv’ saved [1170/1170]

# %%
import pandas as pd
titanic = pd.read_csv("/content/drive/My Drive/app/Titanic.csv")
titanic.head(5)
# Out:
#   File "<ipython-input-6-af0b42de8968>", line 2
#     titanic = pd.read_csv(“/content/drive/My Drive/app/Titanic.csv”)
#                           ^
# SyntaxError: invalid character in identifier

# %%
import pandas as pd
titanic = pd.read_csv("/content/drive/My Drive/app/Titanic.csv")
titanic.head(5)
# Out:
#    Unnamed: 0 Class     Sex    Age Survived  Freq
# 0           1   1st    Male  Child       No     0
# 1           2   2nd    Male  Child       No     0
# 2           3   3rd    Male  Child       No    35
# 3           4  Crew    Male  Child       No     0
# 4           5   1st  Female  Child       No     0

# %%
# !git clone https://github.com/wxs/keras-mnist-tutorial.git
# Out:
# Cloning into 'keras-mnist-tutorial'...
# remote: Enumerating objects: 26, done.
# remote: Total 26 (delta 0), reused 0 (delta 0), pack-reused 26
# Unpacking objects: 100% (26/26), done.

# %%
# !git clone https://github.com/wxs/keras-mnist-tutorial.git
# Out:
# fatal: destination path 'keras-mnist-tutorial' already exists and is not an empty directory.
