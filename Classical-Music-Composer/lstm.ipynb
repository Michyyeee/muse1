# %%
""" This module prepares midi file data and feeds it to the neural
    network for training """
import glob
import pickle
import numpy
from music21 import converter, instrument, note, chord
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

def train_network():
    """ Train a Neural Network to generate music """
    notes = get_notes()

    # get amount of pitch names
    n_vocab = len(set(notes))

    network_input, network_output = prepare_sequences(notes, n_vocab)

    model = create_network(network_input, n_vocab)

    train(model, network_input, network_output)

def get_notes():
    """ Get all the notes and chords from the midi files in the ./midi_songs directory """
    notes = []

    for file in glob.glob("/content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/*.mid"):
        midi = converter.parse(file)

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes

        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

    with open('/content/drive/My Drive/app/Classical-Piano-Composer-master/data/notes', 'wb') as filepath:
        pickle.dump(notes, filepath)

    return notes

def prepare_sequences(notes, n_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 100

    # get all pitch names
    pitchnames = sorted(set(item for item in notes))

     # create a dictionary to map pitches to integers
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

    network_input = []
    network_output = []

    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        network_output.append(note_to_int[sequence_out])

    n_patterns = len(network_input)

    # reshape the input into a format compatible with LSTM layers
    network_input = numpy.reshape(network_input, (n_patterns, sequence_length, 1))
    # normalize input
    network_input = network_input / float(n_vocab)

    network_output = np_utils.to_categorical(network_output)

    return (network_input, network_output)

def create_network(network_input, n_vocab):
    """ create the structure of the neural network """
    model = Sequential()
    model.add(LSTM(
        512,
        input_shape=(network_input.shape[1], network_input.shape[2]),
        recurrent_dropout=0.3,
        return_sequences=True
    ))
    model.add(LSTM(512, return_sequences=True, recurrent_dropout=0.3,))
    model.add(LSTM(512))
    model.add(BatchNorm())
    model.add(Dropout(0.3))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(BatchNorm())
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

    return model

def train(model, network_input, network_output):
    """ train the neural network """
    filepath = "weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
    checkpoint = ModelCheckpoint(
        filepath,
        monitor='loss',
        verbose=0,
        save_best_only=True,
        mode='min'
    )
    callbacks_list = [checkpoint]

    model.fit(network_input, network_output, epochs=5, batch_size=128, callbacks=callbacks_list)

if __name__ == '__main__':
    train_network()
# Out:
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Ff7-One_Winged.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/traitor.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/dayafter.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Kingdom_Hearts_Dearly_Beloved.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Zelda_Overworld.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff6shap.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/gerudo.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff4_piano_collections-main_theme.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/fortresscondor.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Eternal_Harvest.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/rufus.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Still_Alive-1.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/z_aeristhemepiano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff7themep.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/electric_de_chocobo.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/braska.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/dontbeafraid.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Fierce_Battle_(Piano).mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FF3_Third_Phase_Final_(Piano).mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/bcm.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FF8_Shuffle_or_boogie_pc.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Finalfantasy6fanfarecomplete.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ViviinAlexandria.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/tpirtsd-piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/costadsol.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Finalfantasy5gilgameshp.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/tifap.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Ff7-Cinco.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/figaro.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/thenightmarebegins.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/thoughts.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/VincentPiano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Oppressed.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff4-town.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Fyw_piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff4-fight1.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/mining.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Kingdom_Hearts_Traverse_Town.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/caitsith.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Fiend_Battle_(Piano).mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff7-mainmidi.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Gold_Silver_Rival_Battle.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FFVII_BATTLE.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ultimafro.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Cids.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/great_war.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Rydia_pc.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/BlueStone_LastDungeon.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/sobf.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/path_of_repentance.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/waltz_de_choco.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Final_Fantasy_Matouyas_Cave_Piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Ff7-Jenova_Absolute.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/EyesOnMePiano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/goldsaucer.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FF4.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FF3_Battle_(Piano).mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/JENOVA.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/pkelite4.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/decisive.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/lurk_in_dark.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/balamb.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FFIXQuMarshP.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/8.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/In_Zanarkand.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FF6epitaph_piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/sandy.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/cosmo.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/AT.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff8-lfp.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff11_awakening_piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FFIX_Piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/relmstheme-piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff1battp.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Rachel_Piano_tempofix.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/roseofmay-piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Life_Stream.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff4pclov.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/DOS.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ff4-airship.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/sera_.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/HighwindTakestotheSkies.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/0fithos.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ultros.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/redwings.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/OTD5YA.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Ff4-BattleLust.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/Final_Fantasy_7_-_Judgement_Day_Piano.mid
# Parsing /content/drive/My Drive/app/Classical-Piano-Composer-master/midi_songs/ahead_on_our_way_piano.mid
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/200
# 446/446 [==============================] - 239s 535ms/step - loss: 5.1666
# Epoch 2/200
# 446/446 [==============================] - 239s 535ms/step - loss: 4.7485
# Epoch 3/200
# 446/446 [==============================] - 243s 544ms/step - loss: 4.5926
# Epoch 4/200
# 446/446 [==============================] - 238s 533ms/step - loss: 4.5566
# Epoch 5/200
# 446/446 [==============================] - 238s 534ms/step - loss: 4.5341
# Epoch 6/200
# 446/446 [==============================] - 239s 535ms/step - loss: 4.5145
# Epoch 7/200
# 446/446 [==============================] - 238s 534ms/step - loss: 4.5152
# Epoch 8/200
# 446/446 [==============================] - 238s 533ms/step - loss: 4.4915
# Epoch 9/200
# 446/446 [==============================] - 238s 534ms/step - loss: 4.4783
# Epoch 10/200
# 446/446 [==============================] - 240s 539ms/step - loss: 4.4681
# Epoch 11/200
# 446/446 [==============================] - 242s 543ms/step - loss: 4.4422
# Epoch 12/200
# 446/446 [==============================] - 242s 542ms/step - loss: 4.4213
# Epoch 13/200
# 446/446 [==============================] - 246s 552ms/step - loss: 4.4008
# Epoch 14/200
# 446/446 [==============================] - 247s 553ms/step - loss: 4.3946
# Epoch 15/200
# 446/446 [==============================] - 245s 550ms/step - loss: 4.3795
# Epoch 16/200
# 446/446 [==============================] - 246s 551ms/step - loss: 4.3692
# Epoch 17/200
# 446/446 [==============================] - 248s 556ms/step - loss: 4.3474
# Epoch 18/200
# 446/446 [==============================] - 248s 556ms/step - loss: 4.3268
# Epoch 19/200
# 446/446 [==============================] - 254s 570ms/step - loss: 4.3132
# Epoch 20/200
# 446/446 [==============================] - 254s 570ms/step - loss: 4.2886
# Epoch 21/200
# 446/446 [==============================] - 253s 568ms/step - loss: 4.2665
# Epoch 22/200
# 446/446 [==============================] - 255s 572ms/step - loss: 4.2499
# Epoch 23/200
# 446/446 [==============================] - 257s 577ms/step - loss: 4.2253
# Epoch 24/200
# 446/446 [==============================] - 260s 582ms/step - loss: 4.2048
# Epoch 25/200
# 446/446 [==============================] - 261s 585ms/step - loss: 4.1800
# Epoch 26/200
# 446/446 [==============================] - 258s 578ms/step - loss: 4.1465
# Epoch 27/200
# 446/446 [==============================] - 255s 572ms/step - loss: 4.1112
# Epoch 28/200
# 446/446 [==============================] - 258s 579ms/step - loss: 4.0861
# Epoch 29/200
# 446/446 [==============================] - 261s 585ms/step - loss: 4.0433
# Epoch 30/200
# 446/446 [==============================] - 261s 584ms/step - loss: 4.0081
# Epoch 31/200
# 446/446 [==============================] - 260s 582ms/step - loss: 3.9629
# Epoch 32/200
